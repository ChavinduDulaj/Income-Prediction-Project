# %%
import pandas as pd

# %%
file_path = r"C:\Users\ASUS\Desktop\Machine Learning\Income-Prediction-Project\adult\adult.data"

# %%
#Define the columns names
column_names = [
    "Age",
    "Workclass",
    "Final Weight",
    "Education",
    "Years of Education",
    "Marital Status",
    "Occupation",
    "Relationship",
    "Race",
    "Sex",
    "Capital Gain",
    "Capital Loss",
    "Hours per Week",
    "Country",
    "Income"
]

# %%
df = pd.read_csv(file_path, names=column_names, delimiter=',\s*', engine='python')

# %%
df
# Out:
#        Age         Workclass  Final Weight   Education  Years of Education  \
# 0       39         State-gov         77516   Bachelors                  13
# 1       50  Self-emp-not-inc         83311   Bachelors                  13
# 2       38           Private        215646     HS-grad                   9
# 3       53           Private        234721        11th                   7
# 4       28           Private        338409   Bachelors                  13
# ...    ...               ...           ...         ...                 ...
# 32556   27           Private        257302  Assoc-acdm                  12
# 32557   40           Private        154374     HS-grad                   9
# 32558   58           Private        151910     HS-grad                   9
# 32559   22           Private        201490     HS-grad                   9
# 32560   52      Self-emp-inc        287927     HS-grad                   9
#
# ...

# %%
import os

# %%
directory = 'dataset'
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
csv_file_path = os.path.join(directory, 'adult.csv')
df.to_csv(csv_file_path, index=False)
print(f"CSV file saved succesfully at: {csv_file_path}")
# Out:
# CSV file saved succesfully at: dataset\adult.csv

# %%
df = pd.read_csv(r'dataset\adult.csv')
df
# Out:
#        Age         Workclass  Final Weight   Education  Years of Education  \
# 0       39         State-gov         77516   Bachelors                  13
# 1       50  Self-emp-not-inc         83311   Bachelors                  13
# 2       38           Private        215646     HS-grad                   9
# 3       53           Private        234721        11th                   7
# 4       28           Private        338409   Bachelors                  13
# ...    ...               ...           ...         ...                 ...
# 32556   27           Private        257302  Assoc-acdm                  12
# 32557   40           Private        154374     HS-grad                   9
# 32558   58           Private        151910     HS-grad                   9
# 32559   22           Private        201490     HS-grad                   9
# 32560   52      Self-emp-inc        287927     HS-grad                   9
#
# ...

# %%
# finding null values is exsit
df.isnull().sum()
# Out:
# Age                   0
# Workclass             0
# Final Weight          0
# Education             0
# Years of Education    0
# Marital Status        0
# Occupation            0
# Relationship          0
# Race                  0
# Sex                   0
# Capital Gain          0
# Capital Loss          0
# Hours per Week        0
# Country               0
# Income                0
# dtype: int64

# %%
null_values = df.isnull().any()
null_values
# Out:
# Age                   False
# Workclass             False
# Final Weight          False
# Education             False
# Years of Education    False
# Marital Status        False
# Occupation            False
# Relationship          False
# Race                  False
# Sex                   False
# Capital Gain          False
# Capital Loss          False
# Hours per Week        False
# Country               False
# Income                False
# dtype: bool

# %%
# Iterate through each column and print unique values
for column in df.columns:
    unique_values = df[column].unique()
    print()
    print(f"Unique values in column '{column}':")
    print()
    print(unique_values)
# Out:
# Unique values in column 'Age':
#
# [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# Unique values in column 'Workclass':
#
# ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
# Unique values in column 'Final Weight':
#
# [ 77516  83311 215646 ...  34066  84661 257302]
#
# Unique values in column 'Education':
#
# ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
#
# Unique values in column 'Years of Education':
#
# [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# Unique values in column 'Marital Status':
#
# ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
# ...

# %%
# Specify the columns to check for zero values
columns_to_check = ["Age", "Final Weight", "Years of Education", "Capital Gain", "Capital Loss", "Hours per Week"]

# Check if there are any zero values in the DataFrame
if (df == 0).any().any():
    print("Columns containing zero values:")
    # Iterate through each column
    for column in df.columns:
        # Check if any zero values are present in the column
        if (df[column] == 0).any():
            print(f"Column '{column}':")
            # Print the rows where zero values occur in that column
            zero_rows = df[df[column] == 0]
            print(zero_rows)
            print()  # Print an empty line for separation
else:
    print("There are no zero values in the DataFrame.")
# Out:
# Columns containing zero values:
# Column 'Capital Gain':
#        Age         Workclass  Final Weight     Education  Years of Education  \
# 1       50  Self-emp-not-inc         83311     Bachelors                  13
# 2       38           Private        215646       HS-grad                   9
# 3       53           Private        234721          11th                   7
# 4       28           Private        338409     Bachelors                  13
# 5       37           Private        284582       Masters                  14
# ...    ...               ...           ...           ...                 ...
# 32555   22           Private        310152  Some-college                  10
# 32556   27           Private        257302    Assoc-acdm                  12
# 32557   40           Private        154374       HS-grad                   9
# 32558   58           Private        151910       HS-grad                   9
# ...
